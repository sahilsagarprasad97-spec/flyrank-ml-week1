# %% [markdown]
# # Week 2 - Portfolio Case Study
#
# ## Voice Card
#
# Direct, honest, practical, clear, friendly, simple.

# %% [markdown]
# ## Interview
#
# ### Question 1
# What problem were you trying to solve?
#
# **Answer:**
# I wanted to understand how to frame a real-world problem as a Machine Learning task and complete the internship assignment correctly.
#
# ### Question 2
# What decisions did you make?
#
# **Answer:**
# I selected Classification as the ML task type, defined the target variable, chose Accuracy and F1 Score as the success metrics, and created a sample dataset.
#
# ### Question 3
# What was the outcome?
#
# **Answer:**
# I completed the notebook successfully, uploaded it to GitHub, and prepared it for submission.

# %% [markdown]
# ## Case Study
#
# ### Problem
#
# The task was to map a real-world problem into a Machine Learning task.
#
# ### What I Did
#
# I identified the ML task type, selected the target variable, defined the success metrics, created a sample dataset, and explained my reasoning in the notebook.
#
# ### Outcome
#
# The notebook was completed successfully, uploaded to GitHub, and submitted for the internship assignment.

# %% [markdown]
# ## Bio
#
# I am a B.Tech Computer Science and Engineering (Data Science) student with an interest in Machine Learning, Artificial Intelligence, and Data Science. I enjoy learning through practical projects and continuously improving my technical skills.
#
# ## Contact
#
# GitHub:
# https://github.com/sahilsagarprasad97-spec
#
# Thank you for visiting my portfolio.
